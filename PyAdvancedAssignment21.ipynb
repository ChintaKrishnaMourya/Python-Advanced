# %% [markdown]
# ### Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?
#
#  probability distribution is a mathematical function describes the likelihood of getting the possible values of a random variable.
#
#  IF the values of a random variable are meant to be random, probability distribution a way to describe the uncertainty of the values by assigning probabilities to the different possible outcomes. Outcome will be based on probability of its occurence

# %% [markdown]
# ### Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?
# True random numbers are true values and pseudo random numbers are generated by program. Latter is good because they are in uniform distribution.

# %% [markdown]
# ### Q3. What are the two main factors that influence the behaviour of a &quot;normal&quot; probability distribution?
#
# Mean and Variance influence the behaviour of the "normal" probability distribution.

# %% [markdown]
# ### Q4. Provide a real-life example of a normal distribution.
#
# height of humans. If we measure height of large number of humans, the resu;t will form bell shaped curve. Bell shaped curve represents normal distribution.

# %% [markdown]
# ### Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?
#
# Expecting a Probability distribution to behave is unpredictable. If we incrase number of trails, it will be easy to predict the outcome. Because outcomes are clusted around mean.

# %% [markdown]
# ### Q6. What kind of object can be shuffled by using random.shuffle?
#
# list, strings, tuples objects can be shuffled by using random.shuffle

# %% [markdown]
# ### Q7. Describe the math package&#39;s general categories of functions.
# Math package provides a variety of functions : Trignometry, Exponential and Logarithm9ic, Rounding and Precision, Constants like pie, e and etc

# %% [markdown]
# ### Q8. What is the relationship between exponentiation and logarithms?
#
# exponentiation and logarithms are inverse operations.
#
# log_a(y) = n --> logarithm
#
# y = a^n --> Exponential

# %% [markdown]
# ### Q9. What are the three logarithmic functions that Python supports?
#
# log with base "e", "10", "2"
